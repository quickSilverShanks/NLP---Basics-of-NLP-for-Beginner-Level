# %%
import tweepy
import re
import pickle
from tweepy import OAuthHandler

# %%
# Initializing the keys
consumer_key = 'zzhDmLCUo5eNqXIc0c44M5eZw'
consumer_secret = 'LRNlGR4Ye8qBblqXBMLfWJmnKokpB7h4GPXC5QmOGzOIyiSdNy'
access_token = '1248951228349829126-Gzkc82DJPnJEwN1JUssTWqawmciwOR'
access_secret = 'Kr2VoC3ePZxHK0Aaj3kTG2joQMdOVDniZnoOZzncChbes'

# %%
auth = OAuthHandler(consumer_key,consumer_secret) #verifying authenticity of application
auth.set_access_token(access_token,access_secret) #verifying if you have right to fetch tweets
args = ['facebook'] #search token
api = tweepy.API(auth,timeout=10) #if nothing found, disconnect after 10 sec.

# %%
# Fetch real time tweets

list_tweets = []
query = args[0]
if len(args)==1:
    for status in tweepy.Cursor(api.search,q=query+" -filter:retweets",lang='en',result_type='recent').items(100):
        list_tweets.append(status.text) #status is a json object
list_tweets
# Out:
# ['Facebook: Recall Governor Whitmer - Sign the Petition! https://t.co/smyvDEYdfb via @Change',
#  '@ivanedlm Ni Facebook, ni WhatsApp',
#  'Not to be missed today. Catch @TheBinaryLion as he showcases his Sunset Live Stream Mix this evening. \n\nStream To G… https://t.co/5CShUH7MVy',
#  '@TheWitchMilita Their facebook presence is a real spectacle.',
#  "There's this one girl in a YA Facebook group who refuses to buy new, limited edition books and keeps asking if some… https://t.co/CmA2WfITYq",
#  'Corona Virus Cure Banned From FaceBook https://t.co/HZ8gUIEvYu via @YouTube',
#  'Please share this post\nHelping parents to engage their kids aged 4-12 to learn.Providing a creative learning projec… https://t.co/2xQ9fvj1hT',
#  'Last nights stream available to view again via Facebook: https://t.co/mVyTeUMENw and Youtube: https://t.co/SmWyMBg8Nf',
#  'CHRIST IS RISEN!  ALLELUIA!\n\nEnjoy an Easter greeting from members of Muhlenberg Lutheran Church, and keep the cele… https://t.co/JWNlGIwjuX',
#  'Scrolling through my Facebook timeline for the first time in years\n\nI have no idea who any of these people are',
#  'Watch Fr Christopher’s Easter message here #horbury #horburybridge  https://t.co/MaRBxvq6bC',
#  'See Kenny Rogers Talk Origins of ‘Lady’ in Last On-Camera Interview   #livemusic #blues #jazz #country #kpop #rap… https://t.co/eZkG1Q25mX',
#  'Makhafula Vilakazi Live on Facebook “an ode to the fat black woman in the township ohlanganisa kuhlangane abantwana… https://t.co/jnfW77Ttkz',
#  "@gordonkiernan What's the world coming too when they share Facebook Twitter accounts hug trees eat vegan food even… https://t.co/2kw64QuMC1",
#  'Wishing that the blessings of Easter fill your heart and your home. #HappyEaster 💐 https://t.co/7VCs0ZZSEL https://t.co/FZAtbQATLA',
#  'Let’s destroy our friendship! #BoardKings https://t.co/f6jGAamJRy https://t.co/6TWTyMf8mY https://t.co/f6jGAamJRy',
#  'Everyone: "People are spending so much more time on #SocialMedia📱"\n\nThat\'s true 👉so let us help paint the full pict… https://t.co/FKXPE36owt',
#  'Christ is risen! He Lives! Celebrate with us at 10:30 - our Easter morning service will be live streamed on Faceboo… https://t.co/1nmcbnQeWV',
#  '@keunauwu @SB19Official facebook live\n\n@SB19Official #SB19\n#SB19EasterWithATIN',
#  'I want so badly to repost this on Facebook, but I am not in the mood for dumb ass people to argue how businesses sh… https://t.co/2CtT1JcYeY',
#  'MY EASTER SUNDAY SERMON. DATA MAY BE AN ISSUE BUT TRY TO LISTEN TO THIS MESSAGE IT WILL CHANGE A LOT ABOUT YOUR CUR… https://t.co/n2DO4oAdIN',
#  '@MrCracknell @oldtot Hi Crackers. I haven’t got Facebook after they refused to allow me back in after my account wa… https://t.co/lbcNxILafN']

# %%
# Unpickling the classifier and vectorizer
with open('classifier.pickle','rb') as f:
    clf = pickle.load(f)
with open('tfidfmodel.pickle','rb') as f:
    tfidf = pickle.load(f)

# %%
#checking if it works
clf.predict(tfidf.transform(['You are a very amazing person']))
# Out:
# array([1])

# %%
# Preprocessing & Sentiment classification

for tweet in list_tweets:
    tweet = re.sub(r'^http://t.co/[a-zA-Z0-9]*\s',' ',tweet)
    tweet = re.sub(r'\s+https://t.co/[a-zA-Z0-9]*\s',' ',tweet)
    tweet = re.sub(r'\s+https://t.co/[a-zA-Z0-9]*$',' ',tweet)
    tweet = tweet.lower()
    tweet = re.sub(r"that's","that is",tweet)
    tweet = re.sub(r"there's","there is",tweet)
    tweet = re.sub(r"what's","what is",tweet)
    tweet = re.sub(r"where's","where is",tweet)
    tweet = re.sub(r"it's","it is",tweet)
    tweet = re.sub(r"who's","who is",tweet)
    tweet = re.sub(r"i'm","i am",tweet)
    tweet = re.sub(r"she's","she is",tweet)
    tweet = re.sub(r"he's","he is",tweet)
    tweet = re.sub(r"they're","they are",tweet)
    tweet = re.sub(r"who're","who are",tweet)
    tweet = re.sub(r"ain't","am not",tweet)
    tweet = re.sub(r"wouldn't","would not",tweet)
    tweet = re.sub(r"shouldn't","should not",tweet)
    tweet = re.sub(r"can't","can not",tweet)
    tweet = re.sub(r"couldn't","could not",tweet)
    tweet = re.sub(r"won't","will not",tweet)
    tweet = re.sub(r'\W',' ',tweet)
    tweet = re.sub(r'\d',' ',tweet)
    tweet = re.sub(r'\s+[a-z]\s+',' ',tweet)
    tweet = re.sub(r'\s+[a-z]$',' ',tweet)
    tweet = re.sub(r'^[a-z]\s+',' ',tweet)
    print(tweet)
    sent = clf.predict(tfidf.transform([tweet]).toarray())
    print("Sentiment :",sent)
# Out:
# facebook  recall governor whitmer   sign the petition  via  change
# Sentiment : [1]
#  ivanedlm ni facebook  ni whatsapp
# Sentiment : [0]
# not to be missed today  catch  thebinarylion as he showcases his sunset live stream mix this evening    stream to
# Sentiment : [0]
#  thewitchmilita their facebook presence is real spectacle
# Sentiment : [0]
# there is this one girl in ya facebook group who refuses to buy new  limited edition books and keeps asking if some
# Sentiment : [1]
# corona virus cure banned from facebook via  youtube
# Sentiment : [0]
# please share this post helping parents to engage their kids aged      to learn providing creative learning projec
# Sentiment : [1]
# last nights stream available to view again via facebook  and youtube
# Sentiment : [1]
# christ is risen   alleluia   enjoy an easter greeting from members of muhlenberg lutheran church  and keep the cele
# Sentiment : [1]
# scrolling through my facebook timeline for the first time in years have no idea who any of these people are
# Sentiment : [1]
# watch fr christopher easter message here  horbury  horburybridge
# Sentiment : [0]
# see kenny rogers talk origins of  lady  in last on camera interview    livemusic  blues  jazz  country  kpop  rap
# Sentiment : [1]
# makhafula vilakazi live on facebook  an ode to the fat black woman in the township ohlanganisa kuhlangane abantwana
# Sentiment : [0]
#  gordonkiernan what is the world coming too when they share facebook twitter accounts hug trees eat vegan food even
# Sentiment : [1]
# wishing that the blessings of easter fill your heart and your home   happyeaster
# Sentiment : [1]
# let destroy our friendship   boardkings https co  twtymf my
# Sentiment : [1]
# everyone   people are spending so much more time on  socialmedia    that is true  so let us help paint the full pict
# Sentiment : [1]
# christ is risen  he lives  celebrate with us at         our easter morning service will be live streamed on faceboo
# Sentiment : [1]
#  keunauwu  sb  official facebook live   sb  official  sb    sb  easterwithatin
# Sentiment : [1]
#  ktrtrs  respected sir  my name is prasanth and iam from andhra pradesh    sir  today saw video in facebook tha
# Sentiment : [0]
#  read on facebook that there is crowd funded appeal to buy johnson set of cufflinks from harrods to celebrate
# Sentiment : [1]
# stay tuned on our social media accounts to get the latest updates on our event   for more information  reach us thr
# Sentiment : [1]
# spot the  bird  solaceinnature  gogreen
# Sentiment : [1]
# https co  zndpltyhg fao any nhs peeps who are getting married              nhs  nhsheroes
# Sentiment : [1]
# latest shower activity     weather  uksouthweststormchasers  powered by https co hrxcqer
# Sentiment : [1]
# tune in for our facebook live at       am
# Sentiment : [1]
# what are you doing to prevent coronavirus spread in  abiastate   share on facebook and twitter to join the campaign
# Sentiment : [1]
# just watching the sunrise service at home moravian in north carolina   the minister on his own doing the walk from
# Sentiment : [0]
# happy easter thought do few items about the street names of hedon  here the first  acklam road
# Sentiment : [0]
# gold price analysis  ready to attack        after easter   gold  xauusd  forex  crude
# Sentiment : [0]
#  he is risen
# Sentiment : [1]
#  davidgoodings  start making videos like this
# Sentiment : [1]
#    th_century_dk  sarahsackman ok have just asked my highschool facebook for recommendations but to get started v
# Sentiment : [0]
#  zyb morning sweet child of mine been following you for good while am bit more active on twitter than facebook
# Sentiment : [1]
# listening to boyce avenue version of the one that got away with justin vasquez chorus lyrics while thinking abo
# Sentiment : [0]
# the partners are all passionate dog owners who had struggled to find great products for their own dogs and thought
# Sentiment : [1]
#    walk outs and handshakes starting at       bst over on  emiratesfacup facebook and youtube channels    wafc
# Sentiment : [1]
#  mel_navan  lukemitchell__  palacenavan omg ye just seen it on facebook memories  such good night
# Sentiment : [1]
# full version on this easter sunday we are so honoured to share with you most beautiful performance by  amp  hannah he
# Sentiment : [1]
# via gauri khare on angat pangat facebook group and  saeek here on instagram  these besan vadya are so popular at pr
# Sentiment : [1]
# stream mv   airplane       stream wings  boy meets evil  comeback trailer
# Sentiment : [1]
# tonight at  pm of gabby launching of his new worship cover  cover     on youtube  facebook  instagram and soundclou
# Sentiment : [1]
#  lakhilakhi   themba          ulerato_pillay hey  lakhilakhi  why do you infringe members  freedom of expression in
# Sentiment : [1]
#  kieran_alder am so excited to send you tik toks on the app no on facebook now xxx
# Sentiment : [1]
# this is copy of my  sermon  from our facebook livestream service from  billericay rectory on easter sunday on
# Sentiment : [1]
# if you can go to quayside  then let quayside come to you by the power of facebook live  loving  kipperroberts who
# Sentiment : [1]
#  trollfootball still posting facebook memes from      nice
# Sentiment : [1]
#   sunday   th april from  pm  uk   ireland  watch live   mylovelyhorser facebook page  https co vn vgcz
# Sentiment : [1]
# you can still help and donate  view the tweet and visit the up subol society baguio chapter facebook page for more
# Sentiment : [1]
#  dzrufus  davidiadeleke hey  thanks  davidiadeleke  follow us on any of these platforms    youtube
# Sentiment : [1]
#  quiz night   head to our facebook page at  pm for some musical madness    you will need either laptop pc or two
# Sentiment : [1]
# mlm vet turns to internet recruit   reps with    day ad spend
# Sentiment : [1]
# however it is best to let that be led by those who know the topic  if you re trying to learn and understand somethin
# Sentiment : [1]
# tune in with us      angdatingdaantv live bible study  tonight at  pm via livestream  fb
# Sentiment : [1]
#  moneytalkerrtc like them all equally  facebook great  amazon have    gifts from them so they great   apple pr
# Sentiment : [1]
# thank you so much for your support  we have been able to distribute total of    relief packs last april
# Sentiment : [1]
# https co jtomfqsgir               also subscribe
# Sentiment : [1]
#  deansmig  davydryburgh people that are clueless on your facebook might believe that         people went to cheltenham
# Sentiment : [1]
# as an agent with park christmas savings can help you take the stress out of christmas     you can order food  to
# Sentiment : [1]
# what your biggest fear    fri  thshortstories  murder  mystery  suspense  fridaythe  th
# Sentiment : [1]
#  freezydorito what would really prove if you work at facebook is doing   const          if       null      throw ne
# Sentiment : [0]
# according to facebook theres guy in florida my first and last name who also sells furniture  small world
# Sentiment : [1]
# makhafula vilakazi is live on facebook spitting some of the divine shit
# Sentiment : [1]
#  alandaffern below are some suggested facebook groups  https co enbb wzvgl
# Sentiment : [1]
#   sarahjmca  amp stood for moment silence in memory of our patriot dead as encouraged to by newry easter commi
# Sentiment : [1]
#  trollfootball      facebook
# Sentiment : [1]
#  bastemabini  hecklerforever   facebook  twitter they are blocked from using that lol
# Sentiment : [1]
#  ll be performing the classic dickens ghost story  the signalman  tonight on facebook live
# Sentiment : [1]
# doneee
# Sentiment : [1]
# pillars of creation
# Sentiment : [1]
# remember when you could throw digital sheep at people on facebook miss that
# Sentiment : [0]
#  gmanews  the dilg will not file charges against joshua molo  who was reported by his former teachers to police and
# Sentiment : [1]
# here scroll down and you see it
# Sentiment : [1]
# just saw this somewhere on facebook    ali sethi   alisethi
# Sentiment : [0]
# my mixes be so
# Sentiment : [1]
#  centralbedscpt just when thought british police couldn surprise me anymore mean they already ignore groomin
# Sentiment : [1]
# it is  virtual  panto time    it is easter sunday  amp  should be curtain up for our traditional pantomime   this afterno
# Sentiment : [1]
#  will design awesome facebook cover photo  do you want facebook cover photo in your business page   please just or
# Sentiment : [0]
# sunrise service
# Sentiment : [1]
# join the old path live bible study   you can stream our online event via the following   fb
# Sentiment : [1]
# how facebook becomes threat to free speech  so my posting can cause  physical harm   wtf is that  while facebook
# Sentiment : [0]
# happy easter and resurrection sunday family
# Sentiment : [1]
# https co xhly qqpvg if you can at all please support our fundraiser for  doitfordan    thank you
# Sentiment : [1]
# so true   getting old sucks
# Sentiment : [1]
#  kateburkenhs  mkhospital some answers to your questions
# Sentiment : [0]
# watch   coach jinngoy roa of central visayas football association salutes all the country frontliners who are bat
# Sentiment : [0]
# for any chance of success from your facebook page  you have to engage your audience
# Sentiment : [1]
#  thepeeinghuman the work that you guys are doing is absolutely necessary in this hour  we are being pushed away fro
# Sentiment : [0]
#  new group set up to resist home secretary priti patel despicable  racist plot to eject low paid migrant key wor
# Sentiment : [1]
#  happyeastersunday        wishes  messages  quotes  images  facebook and whatsapp statushttps     sdn blogspot com
# Sentiment : [1]
#  irishcurls  there are some good virtual support groups on facebook for breast cancer was diagnosed with stage
# Sentiment : [1]
# thanks to the more than     viewers yesterday for watching my first  onlineconcert    the next one will be on
# Sentiment : [1]
# hey  we re on  facebook  hit us with like
# Sentiment : [1]
#  karanjohar writer of ur movie  takht  chk his facebook post still wanted to hire him for dialogue
# Sentiment : [0]
# your uncle  who used to post on facebook about how this generation lacks common sense  is now swearing at infants
# Sentiment : [0]
# how do get my granny to stop sending me chain messages on facebook
# Sentiment : [0]
# monday guest on fishpal facebook live at   am is paul procter   please add your questions for paul into this fe
# Sentiment : [0]
#  want so badly to repost this on facebook  but am not in the mood for dumb ass people to argue how businesses sh
# Sentiment : [0]
# my easter sunday sermon  data may be an issue but try to listen to this message it will change lot about your cur
# Sentiment : [1]
#  mrcracknell  oldtot hi crackers haven got facebook after they refused to allow me back in after my account wa
# Sentiment : [0]

# %%
# Plotting the result

total_pos = 0
total_neg = 0

for tweet in list_tweets:
    tweet = re.sub(r'^http://t.co/[a-zA-Z0-9]*\s',' ',tweet)
    tweet = re.sub(r'\s+https://t.co/[a-zA-Z0-9]*\s',' ',tweet)
    tweet = re.sub(r'\s+https://t.co/[a-zA-Z0-9]*$',' ',tweet)
    tweet = tweet.lower()
    tweet = re.sub(r"that's","that is",tweet)
    tweet = re.sub(r"there's","there is",tweet)
    tweet = re.sub(r"what's","what is",tweet)
    tweet = re.sub(r"where's","where is",tweet)
    tweet = re.sub(r"it's","it is",tweet)
    tweet = re.sub(r"who's","who is",tweet)
    tweet = re.sub(r"i'm","i am",tweet)
    tweet = re.sub(r"she's","she is",tweet)
    tweet = re.sub(r"he's","he is",tweet)
    tweet = re.sub(r"they're","they are",tweet)
    tweet = re.sub(r"who're","who are",tweet)
    tweet = re.sub(r"ain't","am not",tweet)
    tweet = re.sub(r"wouldn't","would not",tweet)
    tweet = re.sub(r"shouldn't","should not",tweet)
    tweet = re.sub(r"can't","can not",tweet)
    tweet = re.sub(r"couldn't","could not",tweet)
    tweet = re.sub(r"won't","will not",tweet)
    tweet = re.sub(r'\W',' ',tweet)
    tweet = re.sub(r'\d',' ',tweet)
    tweet = re.sub(r'\s+[a-z]\s+',' ',tweet)
    tweet = re.sub(r'\s+[a-z]$',' ',tweet)
    tweet = re.sub(r'^[a-z]\s+',' ',tweet)
    sent = clf.predict(tfidf.transform([tweet]).toarray())
    if sent[0] ==1 :
        total_pos += 1
    else:
        total_neg += 1

# Plotting the bar chart

import matplotlib.pyplot as plt
import numpy as np

objects = ['Positive', 'Negative']
y_pos = np.arange(len(objects))
plt.bar(y_pos, [total_pos,total_neg], alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Number')
plt.title('Number of Positive and Negative Tweets')

plt.show()
